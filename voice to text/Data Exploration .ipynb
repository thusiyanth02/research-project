# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings

warnings.filterwarnings("ignore")

# %%
os.listdir('input')
# Out:
# ['bed',
#  'bird',
#  'cat',
#  'dog',
#  'down',
#  'eight',
#  'find',
#  'five',
#  'four',
#  'go',
#  'happy',
#  'house',
#  'left',
#  'marvin',
#  'nine',
#  'no',
#  'off',
#  'on',
#  'one',
#  'right',
#  'seven',
#  'sheila',
#  'six',
#  'stop',
#  'three',
#  'tree',
#  'two',
#  'up',
#  'wow',
#  'yes',
#  'zero',
#  '_background_noise_']

# %%
train_audio_path = 'input'
samples, sample_rate = librosa.load(train_audio_path+'/yes/0a7c2a8d_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + '/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample_rate)
# Out:
# 16000

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e3d235726c9b> in <module>
# ----> 1 labels=os.listdir(train_audio_path)
#
# NameError: name 'train_audio_path' is not defined

# %%
#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d8b89bc7a997> in <module>
#       1 #find count of each label and plot bar graph
#       2 no_of_recordings=[]
# ----> 3 for label in labels:
#       4     waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
#       5     no_of_recordings.append(len(waves))
#
# NameError: name 'labels' is not defined

# %%
labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.5000e+01, 3.0000e+01, 4.4000e+01, 1.3800e+02, 1.3600e+02,
#         1.7900e+02, 3.6600e+02, 4.3400e+02, 5.9300e+02, 2.1747e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <a list of 10 Patch objects>)

# %%
train_audio_path = 'input/'
all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# yes
# no
# up
# down
# left
# right
# on
# off
# stop
# go

# %%
from sklearn.preprocessing import LabelEncoder

from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

# %%
inputs = Input(shape=(8000,1))

#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.3)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.3)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8000, 1)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2662, 8)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 884, 16)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 876, 32)           4640
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 292, 32)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 292, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 286, 64)           14400
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 95, 64)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 95, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6080)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1556736
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,611,498
# Trainable params: 1,611,498
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_tr, y_tr ,epochs=100, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 17049 samples, validate on 4263 samples
# Epoch 1/100
# 17049/17049 [==============================] - 135s 8ms/step - loss: 2.0470 - acc: 0.2186 - val_loss: 1.7054 - val_acc: 0.3566
#
# Epoch 00001: val_acc improved from -inf to 0.35656, saving model to best_model.hdf5
# Epoch 2/100
# 17049/17049 [==============================] - 132s 8ms/step - loss: 1.4980 - acc: 0.4362 - val_loss: 1.3112 - val_acc: 0.5679
#
# Epoch 00002: val_acc improved from 0.35656 to 0.56791, saving model to best_model.hdf5
# Epoch 3/100
# 17049/17049 [==============================] - 138s 8ms/step - loss: 1.2777 - acc: 0.5400 - val_loss: 1.1007 - val_acc: 0.6392
#
# Epoch 00003: val_acc improved from 0.56791 to 0.63922, saving model to best_model.hdf5
# Epoch 4/100
# 17049/17049 [==============================] - 145s 8ms/step - loss: 1.1302 - acc: 0.6036 - val_loss: 1.0883 - val_acc: 0.6249
#
# Epoch 00004: val_acc did not improve from 0.63922
# Epoch 5/100
# 17049/17049 [==============================] - 142s 8ms/step - loss: 0.9884 - acc: 0.6537 - val_loss: 0.8862 - val_acc: 0.7192
#
# Epoch 00005: val_acc improved from 0.63922 to 0.71921, saving model to best_model.hdf5
# Epoch 6/100
# 17049/17049 [==============================] - 166s 10ms/step - loss: 0.8677 - acc: 0.7058 - val_loss: 0.8140 - val_acc: 0.7270
#
# Epoch 00006: val_acc improved from 0.71921 to 0.72695, saving model to best_model.hdf5
# Epoch 7/100
# 17049/17049 [==============================] - 147s 9ms/step - loss: 0.7745 - acc: 0.7366 - val_loss: 0.7368 - val_acc: 0.7492
#
# Epoch 00007: val_acc improved from 0.72695 to 0.74924, saving model to best_model.hdf5
# Epoch 8/100
# 17049/17049 [==============================] - 149s 9ms/step - loss: 0.7068 - acc: 0.7585 - val_loss: 0.7126 - val_acc: 0.7696
#
# Epoch 00008: val_acc improved from 0.74924 to 0.76965, saving model to best_model.hdf5
# Epoch 9/100
# 17049/17049 [==============================] - 148s 9ms/step - loss: 0.6595 - acc: 0.7798 - val_loss: 0.6288 - val_acc: 0.7954
#
# Epoch 00009: val_acc improved from 0.76965 to 0.79545, saving model to best_model.hdf5
# Epoch 10/100
# 17049/17049 [==============================] - 152s 9ms/step - loss: 0.6129 - acc: 0.7890 - val_loss: 0.5717 - val_acc: 0.8130
#
# Epoch 00010: val_acc improved from 0.79545 to 0.81304, saving model to best_model.hdf5
# Epoch 11/100
# 17049/17049 [==============================] - 150s 9ms/step - loss: 0.5791 - acc: 0.7997 - val_loss: 0.5592 - val_acc: 0.8034
#
# Epoch 00011: val_acc did not improve from 0.81304
# Epoch 12/100
# 17049/17049 [==============================] - 144s 8ms/step - loss: 0.5462 - acc: 0.8151 - val_loss: 0.6965 - val_acc: 0.7650
#
# Epoch 00012: val_acc did not improve from 0.81304
# Epoch 13/100
# 17049/17049 [==============================] - 142s 8ms/step - loss: 0.5306 - acc: 0.8193 - val_loss: 0.5236 - val_acc: 0.8262
#
# Epoch 00013: val_acc improved from 0.81304 to 0.82618, saving model to best_model.hdf5
# Epoch 14/100
# 17049/17049 [==============================] - 140s 8ms/step - loss: 0.5096 - acc: 0.8261 - val_loss: 0.5424 - val_acc: 0.8187
#
# Epoch 00014: val_acc did not improve from 0.82618
# Epoch 15/100
# 17049/17049 [==============================] - 137s 8ms/step - loss: 0.4922 - acc: 0.8267 - val_loss: 0.5103 - val_acc: 0.8292
#
# Epoch 00015: val_acc improved from 0.82618 to 0.82923, saving model to best_model.hdf5
# Epoch 16/100
# 17049/17049 [==============================] - 134s 8ms/step - loss: 0.4702 - acc: 0.8396 - val_loss: 0.5223 - val_acc: 0.8187
#
# Epoch 00016: val_acc did not improve from 0.82923
# Epoch 17/100
# 17049/17049 [==============================] - 136s 8ms/step - loss: 0.4577 - acc: 0.8434 - val_loss: 0.5077 - val_acc: 0.8344
#
# Epoch 00017: val_acc improved from 0.82923 to 0.83439, saving model to best_model.hdf5
# Epoch 18/100
# 17049/17049 [==============================] - 137s 8ms/step - loss: 0.4438 - acc: 0.8496 - val_loss: 0.5238 - val_acc: 0.8227
#
# Epoch 00018: val_acc did not improve from 0.83439
# Epoch 19/100
# 17049/17049 [==============================] - 133s 8ms/step - loss: 0.4291 - acc: 0.8527 - val_loss: 0.5116 - val_acc: 0.8245
#
# Epoch 00019: val_acc did not improve from 0.83439
# Epoch 20/100
# 17049/17049 [==============================] - 135s 8ms/step - loss: 0.4234 - acc: 0.8570 - val_loss: 0.4709 - val_acc: 0.8449
#
# Epoch 00020: val_acc improved from 0.83439 to 0.84494, saving model to best_model.hdf5
# Epoch 21/100
# 17049/17049 [==============================] - 134s 8ms/step - loss: 0.3918 - acc: 0.8647 - val_loss: 0.4574 - val_acc: 0.8414
#
# Epoch 00021: val_acc did not improve from 0.84494
# Epoch 22/100
# 17049/17049 [==============================] - 134s 8ms/step - loss: 0.3891 - acc: 0.8646 - val_loss: 0.4521 - val_acc: 0.8461
#
# Epoch 00022: val_acc improved from 0.84494 to 0.84612, saving model to best_model.hdf5
# Epoch 23/100
# 17049/17049 [==============================] - 133s 8ms/step - loss: 0.3814 - acc: 0.8682 - val_loss: 0.4638 - val_acc: 0.8412
#
# Epoch 00023: val_acc did not improve from 0.84612
# Epoch 24/100
# 17049/17049 [==============================] - 134s 8ms/step - loss: 0.3795 - acc: 0.8696 - val_loss: 0.4649 - val_acc: 0.8510
#
# Epoch 00024: val_acc improved from 0.84612 to 0.85104, saving model to best_model.hdf5
# Epoch 25/100
# 17049/17049 [==============================] - 134s 8ms/step - loss: 0.3599 - acc: 0.8773 - val_loss: 0.4853 - val_acc: 0.8398
#
# Epoch 00025: val_acc did not improve from 0.85104
# Epoch 26/100
# 17049/17049 [==============================] - 135s 8ms/step - loss: 0.3599 - acc: 0.8752 - val_loss: 0.4937 - val_acc: 0.8351
#
# Epoch 00026: val_acc did not improve from 0.85104
# Epoch 27/100
# 17049/17049 [==============================] - 137s 8ms/step - loss: 0.3440 - acc: 0.8829 - val_loss: 0.4906 - val_acc: 0.8433
#
# Epoch 00027: val_acc did not improve from 0.85104
# Epoch 28/100
# 17049/17049 [==============================] - 137s 8ms/step - loss: 0.3348 - acc: 0.8849 - val_loss: 0.4713 - val_acc: 0.8468
#
# Epoch 00028: val_acc did not improve from 0.85104
# Epoch 29/100
# 17049/17049 [==============================] - 138s 8ms/step - loss: 0.3356 - acc: 0.8837 - val_loss: 0.4875 - val_acc: 0.8407
#
# Epoch 00029: val_acc did not improve from 0.85104
# Epoch 30/100
# 17049/17049 [==============================] - 135s 8ms/step - loss: 0.3195 - acc: 0.8920 - val_loss: 0.4757 - val_acc: 0.8459
#
# Epoch 00030: val_acc did not improve from 0.85104
# Epoch 31/100
# 17049/17049 [==============================] - 130s 8ms/step - loss: 0.3225 - acc: 0.8890 - val_loss: 0.4808 - val_acc: 0.8525
#
# Epoch 00031: val_acc improved from 0.85104 to 0.85245, saving model to best_model.hdf5
# Epoch 32/100
# 17049/17049 [==============================] - 132s 8ms/step - loss: 0.3182 - acc: 0.8913 - val_loss: 0.4587 - val_acc: 0.8536
#
# Epoch 00032: val_acc improved from 0.85245 to 0.85362, saving model to best_model.hdf5
# Epoch 00032: early stopping

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
from keras.models import load_model
model=load_model('best_model.hdf5')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Thusiyanth\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4fa7ae465379> in <module>
#       1 import random
# ----> 2 index=random.randint(0,len(x_val)-1)
#       3 samples=x_val[index].ravel()
#       4 print("Audio:",classes[np.argmax(y_val[index])])
#       5 ipd.Audio(samples, rate=8000)
#
# NameError: name 'x_val' is not defined

# %%
print("Text:",predict(samples))
# Out:
# Text: go

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # seconds
filename = 'yes.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# end

# %%
os.listdir('input/find')
# Out:
# ['stop.wav']

# %%
filepath='input/find'

# %%
samples, sample_rate = librosa.load(filepath + '/' + 'stop.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predict(samples)
# Out:
# 'stop'

# %%
from sklearn.externals import joblib
joblib.dump(predict, 'voice.pkl')
# Out:
# ['voice.pkl']
